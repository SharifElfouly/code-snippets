# %%
from PIL import Image
import numpy as np
import cv2
from bounding_box import bounding_box as bb

# %%
loadedImage = cv2.imread('/home/sharif/Documents/sp2-ai-e2e/test.png')
img = cv2.resize(loadedImage, (800,450))
img.shape
# Out:
# (450, 800, 3)

# %%
bbox = bb.add(img, 312, 303, 523, 600, str(10))

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7FEDEC899DA0>

# %% [markdown]
# Crop takes a box (x1, y1, x2, y2)

# %%
Image.fromarray(img).crop((312, 303, 523, 600))
# Out:
# <PIL.Image.Image image mode=RGB size=211x297 at 0x7FEDEC89A128>

# %%
Image.fromarray(img).crop((387, 317, 405, 368))
# Out:
# <PIL.Image.Image image mode=RGB size=18x51 at 0x7FEDEC89A828>
