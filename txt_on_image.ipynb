# %%
from PIL import Image, ImageFont, ImageDraw

# %%
img = Image.open('/home/sharif/Documents/sp2-ai-terminal-benchmarking/data/gold-standard/images/EnBW_i_050011.jpg')

# %%
fnt = ImageFont.truetype('Pillow/Tests/fonts/FreeMono.ttf', 200)

# %%
draw = ImageDraw.Draw(img)
draw.text((600, 0), '23 mph', fill=(255,0,0), font=fnt)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1438x1080 at 0x7FE10C2ECAC8>
